# %%
import pandas as pd
import numpy  as np

# %%
data = pd.read_csv("Data/dpe-v2-tertiaire.csv")
data
# Out:
#                 N°DPE Date_réception_DPE Date_établissement_DPE  \
# 0       2363T1680837R         2023-05-23             2023-05-22
# 1       2269T2615953W         2022-11-05             2022-11-04
# 2       2357T4209637Z         2023-12-07             2023-12-06
# 3       2404T3934296Y         2024-11-07             2024-11-06
# 4       2360T0127880L         2023-01-16             2023-01-15
# ...               ...                ...                    ...
# 366152  2483T2172322T         2024-06-18             2024-06-17
# 366153  2359T1733808W         2023-05-26             2023-05-25
# 366154  2449T1814608F         2024-05-23             2024-05-21
# 366155  2391T3506846W         2023-10-18             2023-10-17
# 366156  2413T3548510J         2024-10-09             2024-10-08
#
#        Date_visite_diagnostiqueur                 Modèle_DPE N°_DPE_remplacé  \
# 0                      2023-05-11  DPE 2006 tertiaire et ERP             NaN
# ...
